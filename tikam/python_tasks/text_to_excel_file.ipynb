# %%
from openpyxl import Workbook
import json
contents=json.loads(open('countries_v2.txt').read())
wb=Workbook()
ws=wb.active
headings=['code']+list(contents['AC'].keys())
ws.append(headings)
for value in contents:
    #print(value)
    data=list(contents[value].values())
    ws.append([value]+data)
    print([value]+data)
   # print(data)
#wb.save("countries1.xlsx")
# Out:
# ['AC', 'Ascension Island', '🇦🇨', 'U+1F1E6 U+1F1E8', 'https://cdn.jsdelivr.net/npm/country-flag-emoji-json@2.0.0/dist/images/AC.svg']
# ['AD', 'Andorra', '🇦🇩', 'U+1F1E6 U+1F1E9', 'https://cdn.jsdelivr.net/npm/country-flag-emoji-json@2.0.0/dist/images/AD.svg']
# ['AE', 'United Arab Emirates', '🇦🇪', 'U+1F1E6 U+1F1EA', 'https://cdn.jsdelivr.net/npm/country-flag-emoji-json@2.0.0/dist/images/AE.svg']
# ['AF', 'Afghanistan', '🇦🇫', 'U+1F1E6 U+1F1EB', 'https://cdn.jsdelivr.net/npm/country-flag-emoji-json@2.0.0/dist/images/AF.svg']
# ['AG', 'Antigua & Barbuda', '🇦🇬', 'U+1F1E6 U+1F1EC', 'https://cdn.jsdelivr.net/npm/country-flag-emoji-json@2.0.0/dist/images/AG.svg']
# ['AI', 'Anguilla', '🇦🇮', 'U+1F1E6 U+1F1EE', 'https://cdn.jsdelivr.net/npm/country-flag-emoji-json@2.0.0/dist/images/AI.svg']
# ['AL', 'Albania', '🇦🇱', 'U+1F1E6 U+1F1F1', 'https://cdn.jsdelivr.net/npm/country-flag-emoji-json@2.0.0/dist/images/AL.svg']
# ...
